# %% [markdown]
# <a href="https://colab.research.google.com/github/navi004/Deep-Learning-CSE4037-/blob/main/DL_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## LAB-1 (Basics of ML and DL)
# ###22MIA1049
# ###Naveen Nidadavolu

# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd
df = pd.read_csv("/content/dataset.csv")
print(df)
# Out:
#                                           Text  Label
# 0                            The movie is good      1
# 1                             The movie is bad      0
# 2  The acting skills of the actor is fantastic      1
# 3                             I am a good boy       1
# 4                               People are bad      0
# 5                        Director is very good      1
# 6                    Heroine is very beautiful      1
# 7                           Story is excellent      1
# 8                 Background score is very bad      0

# %%
df.shape
# Out:
# (9, 2)

# %%
t = df['Text'].values
l = df['Label'].values
print(df.head())
# Out:
#                                           Text  Label
# 0                            The movie is good      1
# 1                             The movie is bad      0
# 2  The acting skills of the actor is fantastic      1
# 3                             I am a good boy       1
# 4                               People are bad      0

# %% [markdown]
# ### Feature Extraction

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
v = CountVectorizer()

v1 = TfidfVectorizer()

f = v.fit_transform(t)
f1 = v1.fit_transform(t)
print(f1)
# Out:
#   (0, 20)	0.5177667294494314
#   (0, 14)	0.5954961696105889
#   (0, 13)	0.33048379647056125
#   (0, 11)	0.5177667294494314
#   (1, 20)	0.5177667294494314
#   (1, 14)	0.5954961696105889
#   (1, 13)	0.33048379647056125
#   (1, 5)	0.5177667294494314
#   (2, 20)	0.5407633463080227
#   (2, 13)	0.17258111956134736
#   (2, 0)	0.3681822267466754
#   (2, 18)	0.3681822267466754
#   (2, 15)	0.3681822267466754
#   (2, 1)	0.3681822267466754
#   (2, 10)	0.3681822267466754
#   (3, 11)	0.4608478760896585
#   (3, 2)	0.62754252250491
#   (3, 7)	0.62754252250491
#   (4, 5)	0.4608478760896585
#   (4, 16)	0.62754252250491
#   (4, 3)	0.62754252250491
#   (5, 13)	0.3091903946935227
#   (5, 11)	0.48440650085519216
#   (5, 8)	0.6596226070168616
#   (5, 21)	0.48440650085519216
#   (6, 13)	0.28219774237861284
#   (6, 21)	0.44211729497728325
#   (6, 12)	0.6020368475759537
#   (6, 6)	0.6020368475759537
#   (7, 13)	0.31461671588106654
#   (7, 19)	0.6711990472610238
#   (7, 9)	0.6711990472610238
#   (8, 13)	0.2580979834079573
#   (8, 5)	0.404360365542265
#   (8, 21)	0.404360365542265
#   (8, 4)	0.5506227476765727
#   (8, 17)	0.5506227476765727

# %% [markdown]
# ### MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier
ml = MLPClassifier()
ml.fit(f1,l)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %% [markdown]
# ### Testing

# %%
text_t = ['The movie is not bad']
text_t1 = v1.transform(text_t)
print(text_t1)
# Out:
#   (0, 5)	0.5177667294494314
#   (0, 13)	0.33048379647056125
#   (0, 14)	0.5954961696105889
#   (0, 20)	0.5177667294494314

# %%
output = ml.predict(text_t1)
print(output)
# Out:
# [0]

# %% [markdown]
# ### SVM Classifier

# %%
from sklearn.svm import SVC
sv = SVC()
sv.fit(f1,l)
# Out:
# SVC()

# %%
svm_output = sv.predict(text_t1)
print(svm_output)
# Out:
# [0]

# %% [markdown]
# ### Naive Baiyes

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(f1,l)
# Out:
# MultinomialNB()

# %%
nb_output = nb.predict(text_t1)
print(nb_output)
# Out:
# [1]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(f1,l)
# Out:
# RandomForestClassifier()

# %%
rf_output = rf.predict(text_t1)
print(rf_output)
# Out:
# [0]
